# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import csv

browser=webdriver.Chrome(executable_path='chromedriver.exe')
url='https://www.sulekha.com/home-builders/noida'
browser.get(url)
see_more=1
while see_more:
	try:
		see_more=browser.find_element_by_id('morebusinesslist')
		see_more.click()
	except:
		see_more=0
	time.sleep(2)
source=browser.page_source
soup=BeautifulSoup(source,'lxml')
lists=soup.find_all('li',{'class':'list-item view-r'})

fields = ['Name', 'Phone', 'Address']
out_file = open('sulekha.csv','w')
csvwriter = csv.DictWriter(out_file, delimiter=',', fieldnames=fields)
details={}
ctr=0
for li in lists:
	ctr+=1
	try:
		name=li.get('data-name')
	except:
		name='Not Found'
	try:

		phone=li.get('data-bvn')
	except:
		phone='Not Found'
	try:

		address=li.find('address').text
	except:
		address='Not Found'
	details['Name']=name
	details['Phone']=phone
	details['Address']=address
	try:
		csvwriter.writerow(details)
		print(ctr)
		print(details)
	except:
		print(ctr)
		print('Error in writing')
# Out:
# 1
# {'Name': 'Cadd Formation', 'Phone': '011-40126745', 'Address': 'Not Found'}
# 2
# {'Name': 'Geeta Devi', 'Phone': '+91 8954262731', 'Address': 'Not Found'}
# 3
# {'Name': 'Perfect space 4u', 'Phone': '011-40166571', 'Address': 'Not Found'}
# 4
# {'Name': 'Interior Design Studio', 'Phone': '+91 9560760311', 'Address': 'Not Found'}
# 5
# {'Name': 'Fabuloso Infrastructure And Services', 'Phone': '+91 9654410754', 'Address': 'Not Found'}
# 6
# {'Name': 'Abdul Bros Whitewash Repairs & Renovation', 'Phone': '+91 9555535396', 'Address': 'Not Found'}
# 7
# {'Name': 'Sangwan Developers Pvt. Ltd.', 'Phone': '+91 9639006800', 'Address': 'Bhagmal Complex ,Office No. 301, 3rd Floor, Sector 15, Noida - 201301'}
# 8
# {'Name': 'Paramjyoti Infra Engineers Pvt. Ltd.', 'Phone': '+91 9911665079', 'Address': 'Not Found'}
# 9
# {'Name': 'Sood Interiors', 'Phone': '+91 9811113583', 'Address': 'Not Found'}
# 10
# {'Name': 'Elite Landcraft India Pvt. Ltd.', 'Phone': '47069575', 'Address': 'Not Found'}
# 11
# {'Name': 'Fashion Aluminium', 'Phone': '+91 9810132787', 'Address': 'Not Found'}
# 12
# {'Name': 'India Glass & Aluminium Works', 'Phone': '+91 9313186143', 'Address': 'Not Found'}
# 13
# {'Name': 'Riyanka Associates', 'Phone': '+91 8459808868', 'Address': 'Not Found'}
# 14
# {'Name': 'Abdul Bros Whitewash Repairs & Renovation', 'Phone': '+91 9555535396', 'Address': 'Not Found'}
# 15
# {'Name': 'Sangwan Developers Pvt. Ltd.', 'Phone': '+91 9639006800', 'Address': 'Bhagmal Complex ,Office No. 301, 3rd Floor, Sector 15, Noida - 201301'}
# 16
# {'Name': 'Bhagwati Projects Pvt. Ltd.', 'Phone': '+91 9811083380', 'Address': 'Office No. F16, Sector 9, Noida - 201301'}
# 17
# {'Name': 'Pande & Associate', 'Phone': '+91 9810484468', 'Address': 'No. A202, Basement, Plot No. F7, Sector 50, Noida - 201301'}
# 18
# {'Name': 'Anand Burman', 'Phone': '+91 9582898484', 'Address': 'House No. A/37, Sector P 3, Surajpur, Greater Noida - 201308'}
# 19
# {'Name': 'Paramjyoti Infra Engineers Pvt. Ltd.', 'Phone': '+91 9911665079', 'Address': 'Not Found'}
# 20
# {'Name': 'Bhavishya Darshan', 'Phone': '2542219', 'Address': 'Shop No. C72, Sector 26, Noida - 201301'}
# 21
# {'Name': 'North Point Business Solutions', 'Phone': '+91 9899987758', 'Address': 'Not Found'}
# 22
# {'Name': 'R.K Construction And Interiors', 'Phone': '+91 9891650790', 'Address': 'Not Found'}
# 23
# {'Name': 'Ashoka Construction Co.', 'Phone': '+91 9810160228', 'Address': 'Not Found'}
# 24
# {'Name': 'Goarla Construction Company', 'Phone': '+91 9958217229', 'Address': 'Not Found'}
# 25
# {'Name': 'Sanskar Associates & Developers Pvt. Ltd.', 'Phone': '+91 9911281777', 'Address': 'No. 12, VDS Market, Sector 51, Noida - 201307'}
# 26
# {'Name': 'Plutus Partners', 'Phone': '+91 9845225369', 'Address': 'Not Found'}
# 27
# {'Name': 'Homz Kraft', 'Phone': '+91 9818638878', 'Address': 'Shop No. 113, Sector 122,Noida Extension, Phase 2, Noida - 201307'}
# 28
# {'Name': 'Sky Real Estate', 'Phone': '+91 9810099079', 'Address': 'Not Found'}
# 29
# {'Name': 'A-One Glass & Aluminium', 'Phone': '+91 9958975101', 'Address': 'Shop No. 5, Main Shaveri Road,Noida Extension, Phase 2, Noida - 201305 Get Directions'}
# 30
# {'Name': 'Samyak Constructions', 'Phone': '+91 9013779846', 'Address': 'Not Found'}
# 31
# {'Name': 'Svarrnim Infrastructures Pvt. Ltd.', 'Phone': '+91 9711003534', 'Address': 'Ocean Complex ,No. 308, P-6, Sector 18, Noida - 201301 Get Directions'}
# 32
# {'Name': 'CSPA Facility Management Pvt. Ltd.', 'Phone': '+91 9811133812', 'Address': 'Bharat Complex ,Office No. 301, Sector 66, Noida - 201307'}
# 33
# {'Name': 'Pravesh Construction', 'Phone': '+91 7073060230', 'Address': 'Balag Enclave ,No. 2, Shaberi, Sector 4, Noida - 201308 Get Directions'}
# 34
# {'Name': 'Ivan Construction', 'Phone': '+91 9990868672', 'Address': 'Not Found'}
# 35
# {'Name': 'SBL CONSTRUCTION PVT LTD', 'Phone': '+91 9999070045', 'Address': 'SBL TOWER, E-170 SECTOR - 63, Noida'}
# 36
# {'Name': 'Third Vendor', 'Phone': '+91 7838060127', 'Address': 'No. B-7, Sector - 1,Harola, Sector 5, Noida - 201301'}
# 37
# {'Name': 'Chhaya Builders Pvt Ltd', 'Phone': '+91 9810529303', 'Address': 'C-303, Sector-10, Sector 10, Noida - 201301'}
# 38
# {'Name': 'V Make Home', 'Phone': '+91 9971977438', 'Address': 'Ground Floor, Sector 53 Main Road, Sector 53, Noida - 201301'}
# 39
# {'Name': 'Elements Nine Build and Design', 'Phone': '+91 9990694936', 'Address': 'Paras tiera, Tower 15, ground floor 005, Sector 15A, Noida - 201301 Get Directions'}
# 40
# {'Name': 'RH DESIGNS', 'Phone': '+91 8750600112', 'Address': 'Not Found'}
# 41
# {'Name': 'Define Dezign', 'Phone': '+91 8802684344', 'Address': '14, Paramount Floraville setor 137, Sector 137, Noida - 201301 Get Directions'}
# 42
# {'Name': 'Facto', 'Phone': '+91 9205203343', 'Address': 'No. C 151, Sector 10, Noida - 201301 Get Directions'}
# 43
# {'Name': 'Mumtiaj Interior & Constructions Co.', 'Phone': '+91 9650593349', 'Address': 'Not Found'}
# 44
# {'Name': 'Kalco Designs', 'Phone': '+91 9811736412', 'Address': 'SF 40, Ansal Fortune Arcade ,Ansal, Sector 18, Noida - 201301'}
# 45
# {'Name': 'Aiis group', 'Phone': '+91 8826110034', 'Address': 'Not Found'}
# 46
# {'Name': 'PKM Tech Corporation', 'Phone': '+91 9350746306', 'Address': 'Not Found'}
# 47
# {'Name': 'M.K. Yadav Constrctor', 'Phone': '+91 9810639194', 'Address': 'morna sec 35, Sector 35, Noida - 201301'}
# 48
# {'Name': 'KSR BuildTech', 'Phone': '+91 8800819173', 'Address': 'Logic Technova, Sector 132, Noida - 201304 Get Directions'}
# 49
# {'Name': 'Worldwide Legal Association', 'Phone': '+91 9999959211', 'Address': 'Krishna Apra Plaza ,No.310, 3rd Floor, P Block, Pocket A, Sector 18, Noida - 201301'}
# 50
# {'Name': 'Amra Interiors & Constructions', 'Phone': '+91 9990980737', 'Address': 'Not Found'}
# 51
# {'Name': 'Navnirman Constructions', 'Phone': '+91 9990796015', 'Address': 'Not Found'}
# 52
# {'Name': 'Foji Steel furniture ', 'Phone': '+91 8077594790', 'Address': 'Village Choura behind h block market sector 22, Fiserv India Ltd. Noida, noida - 201301'}
# 53
# {'Name': 'Building contractor ', 'Phone': '+91 8447151870', 'Address': 'Vridavan garden noida extn, Greater Noida Express Way, Noida - 201009'}
# 54
# {'Name': 'Balaji Engineers', 'Phone': '+91 9891937523', 'Address': 'Gali No.16, C 32. Sector 49, Sector 49, Noida - 201301'}
# 55
# {'Name': 'Mahadev Homes', 'Phone': '+91 9811681890', 'Address': 'Not Found'}
# 56
# {'Name': 'saw contractors', 'Phone': '+91 8920392503', 'Address': '57, block-4, ganga shopping complex, sec-29, noida, Sector 29, Noida - 201301 Get Directions'}
# 57
# {'Name': 'Civil works', 'Phone': '+91 9540067786', 'Address': 'Noida, Noida Extension, noida - 201304 Get Directions'}
# 58
# {'Name': 'Proarc Design Studio', 'Phone': '+91 8860090007', 'Address': 'G-580, ALPHA 2 , GREATER NOIDA, Greater Noida Cd, Noida - 201308'}
# 59
# {'Name': 'GK CONTRACTIONS AND PAINTS ', 'Phone': '+91 9871886542', 'Address': 'Noida - 201301'}
# 60
# {'Name': 'Intirior works', 'Phone': '+91 9990261532', 'Address': 'Noida - 121002'}
# 61
# {'Name': 'RC CONSTRUCTION', 'Phone': '+91 8375047690', 'Address': 'Not Found'}
# 62
# {'Name': 'ArchSpace Architects & Interior Designer In Noida', 'Phone': '+91 8619956207', 'Address': 'Sector 18, Noida'}
# 63
# {'Name': 'Tile', 'Phone': '+91 9354705117', 'Address': 'Noida Extension, Noida - 201009 Get Directions'}
# 64
# {'Name': 'AARTECH ENGINEERS', 'Phone': '+91 8383077377', 'Address': 'Near Glory, Sector 46, Noida, Salarpur, Noida - 201303 Get Directions'}
# 65
# {'Name': 'Construction & Interior contractor', 'Phone': '+91 7982382296', 'Address': 'Khora Colony, Noida'}
# 66
# {'Name': 'Skyscraper Construction & Engineers', 'Phone': '+91 9654646468', 'Address': 'Sector 16A, Noida'}
# 67
# {'Name': 'Ghar Station', 'Phone': '+91 8368214209', 'Address': 'B-442A, Sector 19, noida - 201301'}
# 68
# {'Name': 'Arnick buildcon', 'Phone': '+91 9654629449', 'Address': 'Z443b first floor, Sector 12, Noida - 201301 Get Directions'}
# 69
# {'Name': 'Shri Bala Ji Constructions', 'Phone': '+91 7503956117', 'Address': 'C 348, Sector 10, Noida - 201301'}
# 70
# {'Name': 'Nirala Greenshire Mart ', 'Phone': '+91 9312814501', 'Address': 'Not Found'}
# 71
# {'Name': 'Shri Balaji traders', 'Phone': '+91 6396077001', 'Address': 'A/99 sector 7, Sector 7, noida - 201301 Get Directions'}
# 72
# {'Name': 'BHARDWAJ ASSOCIATES', 'Phone': '+91 9899993780', 'Address': 'Not Found'}
# 73
# {'Name': 'soni construction', 'Phone': '+91 9990392960', 'Address': 'Greater Noida Cd, Noida - 201306'}
# 74
# {'Name': 'Node urban lab', 'Phone': '+91 9457772181', 'Address': 'E 160 sector 63 Noida, Sector 63, noida - 201301 Get Directions'}
# 75
# {'Name': 'Shiva builders', 'Phone': '+91 9818693585', 'Address': 'Phase 2, Noida - 201301'}
# 76
# {'Name': 'Alif Consterior Group     Renovation home, office, comp', 'Phone': '+91 8287503977', 'Address': 'Not Found'}
# 77
# {'Name': 'design squres', 'Phone': '+91 9718991930', 'Address': 'Not Found'}
# 78
# {'Name': 'Brickson', 'Phone': '+91 8595868619', 'Address': 'Noida'}
# 79
# {'Name': 'Home Renovation Construction and Painting Services', 'Phone': '+91 8800805388', 'Address': 'Not Found'}
# 80
# {'Name': 'home/Shop construction contractors', 'Phone': '+91 9149263020', 'Address': 'Noida Extension, Noida'}
# 81
# {'Name': 'dev urbantech engineering', 'Phone': '+91 8449394694', 'Address': 'Bhangel, Noida - 201306'}
# 82
# {'Name': 'Sp construction co', 'Phone': '+91 9716549912', 'Address': 'Noida - 201301'}
# 83
# {'Name': 'Design & Development', 'Phone': '+91 9873923421', 'Address': 'No. 102, Greater Noida Cd, Noida - 201304'}
# 84
# {'Name': 'DM Architecture & Interior\t', 'Phone': '+91 9971286682', 'Address': 'E-77, Ground Floor, Jasola, Jasola, Delhi - 110025 Get Directions'}
# 85
# {'Name': 'Prithu Homes', 'Phone': '+91 9958155663', 'Address': 'Not Found'}
# 86
# {'Name': 'Globus Infratech', 'Phone': '011-41109091', 'Address': 'Not Found'}
# 87
# {'Name': 'Panwar Construction Company', 'Phone': '+91 9716810419', 'Address': 'Not Found'}
# 88
# {'Name': 'Amity Contractors Pvt. Ltd.', 'Phone': '+91 9811778208', 'Address': 'Not Found'}
# 89
# {'Name': 'Homes', 'Phone': '+91 9810028298', 'Address': 'Not Found'}
# 90
# {'Name': 'Home renovation', 'Phone': '+91 9820436098', 'Address': 'Not Found'}
# 91
# {'Name': 'Discovery Infrastructure', 'Phone': '+91 9811505832', 'Address': 'Not Found'}
# 92
# {'Name': 'Home Construction & Interior Co.', 'Phone': '+91 9811212145', 'Address': 'Not Found'}
# 93
# {'Name': 'Dev Home Construction', 'Phone': '+91 9873905566', 'Address': 'Not Found'}
# 94
# {'Name': 'Jagriti Enterprises', 'Phone': '+91 9899128551', 'Address': 'Not Found'}
# 95
# {'Name': ' Shivkay Construction Co.', 'Phone': '+91 9810104531', 'Address': 'Not Found'}
# 96
# {'Name': 'Shahan Enterprises', 'Phone': '+91 9810357601', 'Address': 'Not Found'}
# 97
# {'Name': 'Risers Buildtech OPC Pvt. Ltd.', 'Phone': '+91 9999912425', 'Address': 'Not Found'}
# 98
# {'Name': 'Kishan Construction', 'Phone': '+91 9910377213', 'Address': 'Not Found'}
# 99
# {'Name': 'On Land Construction', 'Phone': '8901547619', 'Address': 'Not Found'}
# 100
# {'Name': 'Wood N Design', 'Phone': '+91 9211685826', 'Address': 'Not Found'}
# 101
# {'Name': 'Gaurav Ahuja Construction', 'Phone': '+91 9810455031', 'Address': 'Not Found'}
# 102
# {'Name': 'M.S. Constructions', 'Phone': '+91 9810154259', 'Address': 'G2, 9/2, Patel Nagar, Delhi - 110005'}
# 103
# {'Name': 'Enhance Events & Production - Best Event Organiser In Lucknow', 'Phone': '011-40017536', 'Address': 'Not Found'}
# 104
# {'Name': 'NS Constructions', 'Phone': '+91 9958175745', 'Address': 'Not Found'}
# 105
# {'Name': 'Imarat Construction', 'Phone': '+91 9560596446', 'Address': 'Not Found'}
# 106
# {'Name': 'Dreamz construction & interiors', 'Phone': '+91 8505991169', 'Address': 'j-130,gamma-2,, Greater Noida Cd, Noida - 201310 Get Directions'}
# 107
# {'Name': 'Anaadi Constructions', 'Phone': '+91 9891149056', 'Address': 'No. 3/294, Barola Road, Sector 49, Noida - 201301'}
# 108
# {'Name': 'Trust Buildcon', 'Phone': '+91 9540049666', 'Address': 'Not Found'}
# 109
# {'Name': 'Ashirwad Mart & interior solution', 'Phone': '+91 8800715783', 'Address': 'No.2, Amrit Plaza Road, Jagat Farm, Greater Noida Cd, Noida - 201310 Get Directions'}
# 110
# {'Name': 'LUV Touch', 'Phone': '+91 9810609938', 'Address': 'Not Found'}
